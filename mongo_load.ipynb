# %%
import pandas as pd
import numpy as np

# %%
departments_df = pd.read_csv("data/departments.csv")
aisles_df = pd.read_csv("data/aisles.csv")
orders_df = pd.read_csv("data/orders.csv")
products_df = pd.read_csv("data/products.csv")
order_products_prior_df = pd.read_csv("data/order_products__prior.csv")

# %% [markdown]
# ### About the following table:
#
# This table has been randomly generated where each user_id is related to a name, location (Address, City and State) , Pin-Code and email address.

# %%
random_us_addresses_df = pd.read_csv("data/random_us_addresses.csv", header= None)

# %% [markdown]
# ### Function to check for NaN values in each column for a table

# %%
def checking_NaN(table):
    for column in table.columns:
        null_values = table[f"{column}"].isnull().sum()
        print(f"{column} - {null_values}")

# %% [markdown]
# ### Checking departments_df for any violations in data and cleaning it

# %%
departments_df
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %% [markdown]
# ### Checking aisles_df for any violations in data and cleaning it

# %%
aisles_df
# Out:
#      aisle_id                       aisle
# 0           1       prepared soups salads
# 1           2           specialty cheeses
# 2           3         energy granola bars
# 3           4               instant foods
# 4           5  marinades meat preparation
# ..        ...                         ...
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes
#
# [134 rows x 2 columns]

# %% [markdown]
# Checking if any duplicate ids or aisles are present

# %%
aisles_df[aisles_df.duplicated(subset=["aisle_id"])]
# Out:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %%
aisles_df[aisles_df.duplicated(subset=["aisle"])]
# Out:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %% [markdown]
# Checking if any aisle_id or aisle is null

# %%
checking_NaN(aisles_df)
# Out:
# aisle_id - 0
# aisle - 0

# %% [markdown]
# ### Checking orders_df for any violations in data and cleaning it

# %%
orders_df
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# 3                        7                    29.0
# 4                       15                    28.0
# ...                    ...                     ...
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
# 3421082                 14                    30.0
#
# [3421083 rows x 7 columns]

# %% [markdown]
# Checking for NaN Values in each column

# %%
checking_NaN(orders_df)
# Out:
# order_id - 0
# user_id - 0
# eval_set - 0
# order_number - 0
# order_dow - 0
# order_hour_of_day - 0
# days_since_prior_order - 206209

# %%
orders_df = orders_df.replace(np.nan,0)

# %%
orders_df
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     0.0
# 1                        7                    15.0
# 2                       12                    21.0
# 3                        7                    29.0
# 4                       15                    28.0
# ...                    ...                     ...
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
# 3421082                 14                    30.0
#
# [3421083 rows x 7 columns]

# %%
orders_df = orders_df.astype({"days_since_prior_order":int})

# %%
orders_df.days_since_prior_order = orders_df.days_since_prior_order.replace(0,"\\N")

# %%
orders_df
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day days_since_prior_order
# 0                        8                     \N
# 1                        7                     15
# 2                       12                     21
# 3                        7                     29
# 4                       15                     28
# ...                    ...                    ...
# 3421078                 18                     29
# 3421079                 10                     30
# 3421080                 12                     18
# 3421081                 12                      7
# 3421082                 14                     30
#
# [3421083 rows x 7 columns]

# %% [markdown]
# Check if combined (order_id, user_id) value is duplicated. This is done since they will be made the primary keys for this table

# %%
orders_df[orders_df.duplicated(subset=["order_id", "user_id"])]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, eval_set, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
def cleaning_orders_df():
    # Dropping eval set column
    orders_df.drop(columns=["eval_set"], inplace=True)
    # Making all the nan values in days_since_prior_order replace with 0
    # orders_df.fillna(0, inplace=True)

# %%
cleaning_orders_df()

# %%
orders_df
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#         days_since_prior_order
# 0                           \N
# 1                           15
# 2                           21
# 3                           29
# 4                           28
# ...                        ...
# 3421078                     29
# 3421079                     30
# 3421080                     18
# 3421081                      7
# 3421082                     30
#
# [3421083 rows x 6 columns]

# %% [markdown]
# ### Checking products_df for any violations in data and cleaning it

# %%
products_df
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
# 49685       49686                                   Artisan Baguette
# 49686       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49687       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# 3            38              1
# 4             5             13
# ...         ...            ...
# 49683       124              5
# 49684        42              1
# 49685       112              3
# 49686        41              8
# 49687        73             11
#
# [49688 rows x 4 columns]

# %% [markdown]
# Checking for NaN values

# %%
checking_NaN(products_df)
# Out:
# product_id - 0
# product_name - 0
# aisle_id - 0
# department_id - 0

# %% [markdown]
# Checking for duplicate values in product_id as it will be the primary key

# %%
products_df[products_df.duplicated(subset=["product_id"])]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %% [markdown]
# Mapping department_df to product_df (department_id)

# %%
products_df['department_id'] = products_df.department_id.map(departments_df.set_index('department_id').department)

# %%
products_df
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
# 49685       49686                                   Artisan Baguette
# 49686       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49687       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id
# 0            61         snacks
# 1           104         pantry
# 2            94      beverages
# 3            38         frozen
# 4             5         pantry
# ...         ...            ...
# 49683       124        alcohol
# 49684        42         frozen
# 49685       112         bakery
# 49686        41           pets
# 49687        73  personal care
#
# [49688 rows x 4 columns]

# %% [markdown]
# Mapping aisle_df to product_df (aisle_id)

# %%
products_df['aisle_id'] = products_df.aisle_id.map(aisles_df.set_index('aisle_id').aisle)

# %%
products_df
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
# 49685       49686                                   Artisan Baguette
# 49686       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49687       49688                             Fresh Foaming Cleanser
#
#                          aisle_id  department_id
# 0                   cookies cakes         snacks
# 1               spices seasonings         pantry
# 2                             tea      beverages
# 3                    frozen meals         frozen
# 4      marinades meat preparation         pantry
# ...                           ...            ...
# 49683                     spirits        alcohol
# 49684     frozen vegan vegetarian         frozen
# 49685                       bread         bakery
# 49686               cat food care           pets
# 49687                 facial care  personal care
#
# [49688 rows x 4 columns]

# %% [markdown]
# ### Checking order_products_prior_df for any violations in data and cleaning it

# %%
order_products_prior_df
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
order_products_prior_df[order_products_prior_df.duplicated(subset=["order_id", "product_id"])]
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %% [markdown]
# Checking for NaN values

# %%
checking_NaN(order_products_prior_df)
# Out:
# order_id - 0
# product_id - 0
# add_to_cart_order - 0
# reordered - 0

# %% [markdown]
# ### Checking random_us_addresses_df for any violations in data and cleaning it

# %%
random_us_addresses_df
# Out:
#                0                1                             2  \
# 0              0     Kelly Norman               530 Kevin Plain
# 1              1  Susan Hernandez             3210 Stuart Union
# 2              2      David Roach          0687 Matthew Circles
# 3              3    Brandon Brown  71413 Dickson Hills Apt. 762
# 4              4    Joshua French  2949 Samantha Wall Suite 216
# ...          ...              ...                           ...
# 3999995  3999995    Pamela Waller     02886 Sara Cove Suite 663
# 3999996  3999996     Jeffrey Lamb              1849 Erin Divide
# 3999997  3999997    Crystal Walsh             02038 Jason Alley
# 3999998  3999998     Joe Davidson               055 Jordan Pass
# 3999999  3999999      Yvette Webb  643 Kayla Junction Suite 782
#
#                        3   4      5                                   6
# 0               Beckstad  DC  10028     kellynorman530@gordon-carey.com
# 1           Port Spencer  VA  88043        susanhernandez3210@ayala.com
# 2            Mallorybury  PW  85734            davidroach0687@chang.com
# 3          Glendachester  PA  61726    brandonbrown71413@hanna-cruz.com
# 4          New Davidview  WI  18740        joshuafrench2949@sanchez.com
# ...                  ...  ..    ...                                 ...
# 3999995        Smithland  NH   9812  pamelawaller02886@serrano-duke.org
# 3999996  Port Kelliville  SC  58072          jeffreylamb1849@dillon.com
# 3999997       Steventown  WI  29788      crystalwalsh02038@jennings.biz
# 3999998       Guzmanfurt  SC  25399   joedavidson055@parker-schmitt.com
# 3999999      North Brian  GA  27195             yvettewebb643@davis.com
#
# [4000000 rows x 7 columns]

# %% [markdown]
# Naming the columns

# %%
random_us_addresses_df.rename(columns= {
    0: "user_id",
    1: "user_name",
    2: "user_address",
    3: "city",
    4: "state",
    5: "pincode",
    6: "user_email",
}, inplace= True )

# %%
random_us_addresses_df
# Out:
#          user_id        user_name                  user_address  \
# 0              0     Kelly Norman               530 Kevin Plain
# 1              1  Susan Hernandez             3210 Stuart Union
# 2              2      David Roach          0687 Matthew Circles
# 3              3    Brandon Brown  71413 Dickson Hills Apt. 762
# 4              4    Joshua French  2949 Samantha Wall Suite 216
# ...          ...              ...                           ...
# 3999995  3999995    Pamela Waller     02886 Sara Cove Suite 663
# 3999996  3999996     Jeffrey Lamb              1849 Erin Divide
# 3999997  3999997    Crystal Walsh             02038 Jason Alley
# 3999998  3999998     Joe Davidson               055 Jordan Pass
# 3999999  3999999      Yvette Webb  643 Kayla Junction Suite 782
#
#                     city state  pincode                          user_email
# 0               Beckstad    DC    10028     kellynorman530@gordon-carey.com
# 1           Port Spencer    VA    88043        susanhernandez3210@ayala.com
# 2            Mallorybury    PW    85734            davidroach0687@chang.com
# 3          Glendachester    PA    61726    brandonbrown71413@hanna-cruz.com
# 4          New Davidview    WI    18740        joshuafrench2949@sanchez.com
# ...                  ...   ...      ...                                 ...
# 3999995        Smithland    NH     9812  pamelawaller02886@serrano-duke.org
# 3999996  Port Kelliville    SC    58072          jeffreylamb1849@dillon.com
# 3999997       Steventown    WI    29788      crystalwalsh02038@jennings.biz
# 3999998       Guzmanfurt    SC    25399   joedavidson055@parker-schmitt.com
# 3999999      North Brian    GA    27195             yvettewebb643@davis.com
#
# [4000000 rows x 7 columns]

# %%
checking_NaN(random_us_addresses_df)
# Out:
# user_id - 0
# user_name - 0
# user_address - 0
# city - 0
# state - 0
# pincode - 0
# user_email - 0

# %% [markdown]
# ### Making order collection

# %%
def datetime(x, y):
    return {"order_dow": x, "order_hour_of_day": y}

# %% [markdown]
# Adding datetime column

# %%
orders_df["datetime"] = orders_df.apply(lambda row: datetime(row["order_dow"], row["order_hour_of_day"]), axis=1)

# %%
orders_df.drop(columns={"order_dow", "order_hour_of_day"}, inplace=True)

# %%
orders_df
# Out:
#          order_id  user_id  order_number days_since_prior_order  \
# 0         2539329        1             1                     \N
# 1         2398795        1             2                     15
# 2          473747        1             3                     21
# 3         2254736        1             4                     29
# 4          431534        1             5                     28
# ...           ...      ...           ...                    ...
# 3421078   2266710   206209            10                     29
# 3421079   1854736   206209            11                     30
# 3421080    626363   206209            12                     18
# 3421081   2977660   206209            13                      7
# 3421082    272231   206209            14                     30
#
#                                           datetime
# 0         {'order_dow': 2, 'order_hour_of_day': 8}
# 1         {'order_dow': 3, 'order_hour_of_day': 7}
# 2        {'order_dow': 3, 'order_hour_of_day': 12}
# 3         {'order_dow': 4, 'order_hour_of_day': 7}
# 4        {'order_dow': 4, 'order_hour_of_day': 15}
# ...                                            ...
# 3421078  {'order_dow': 5, 'order_hour_of_day': 18}
# 3421079  {'order_dow': 4, 'order_hour_of_day': 10}
# 3421080  {'order_dow': 1, 'order_hour_of_day': 12}
# 3421081  {'order_dow': 1, 'order_hour_of_day': 12}
# 3421082  {'order_dow': 6, 'order_hour_of_day': 14}
#
# [3421083 rows x 5 columns]

# %% [markdown]
# Add products column

# %%
order_products_prior_df
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
grouped_series= order_products_prior_df.groupby('order_id').apply(lambda x: {'product_id': x['product_id'].tolist(), 'reordered': x['reordered'].tolist()})

# %%
grouped_df = grouped_series.to_frame()

# %%
grouped_df.reset_index(inplace=True)

# %%
grouped_df.rename(columns={0: "products"}, inplace=True)

# %%
grouped_df
# Out:
#          order_id                                           products
# 0               2  {'product_id': [33120, 28985, 9327, 45918, 300...
# 1               3  {'product_id': [33754, 24838, 17704, 21903, 17...
# 2               4  {'product_id': [46842, 26434, 39758, 27761, 10...
# 3               5  {'product_id': [13176, 15005, 47329, 27966, 23...
# 4               6  {'product_id': [40462, 15873, 41897], 'reorder...
# ...           ...                                                ...
# 3214869   3421079          {'product_id': [30136], 'reordered': [0]}
# 3214870   3421080  {'product_id': [27845, 4932, 18811, 41950, 317...
# 3214871   3421081  {'product_id': [38185, 12218, 32299, 3060, 205...
# 3214872   3421082  {'product_id': [17279, 12738, 16797, 43352, 32...
# 3214873   3421083  {'product_id': [7854, 45309, 21162, 18176, 352...
#
# [3214874 rows x 2 columns]

# %% [markdown]
# Mapping to order_id

# %%
orders_df["products"] = orders_df.order_id.map(grouped_df.set_index('order_id').products)

# %%
orders_df
# Out:
#          order_id  user_id  order_number days_since_prior_order  \
# 0         2539329        1             1                     \N
# 1         2398795        1             2                     15
# 2          473747        1             3                     21
# 3         2254736        1             4                     29
# 4          431534        1             5                     28
# ...           ...      ...           ...                    ...
# 3421078   2266710   206209            10                     29
# 3421079   1854736   206209            11                     30
# 3421080    626363   206209            12                     18
# 3421081   2977660   206209            13                      7
# 3421082    272231   206209            14                     30
#
#                                           datetime  \
# 0         {'order_dow': 2, 'order_hour_of_day': 8}
# 1         {'order_dow': 3, 'order_hour_of_day': 7}
# 2        {'order_dow': 3, 'order_hour_of_day': 12}
# 3         {'order_dow': 4, 'order_hour_of_day': 7}
# 4        {'order_dow': 4, 'order_hour_of_day': 15}
# ...                                            ...
# 3421078  {'order_dow': 5, 'order_hour_of_day': 18}
# 3421079  {'order_dow': 4, 'order_hour_of_day': 10}
# 3421080  {'order_dow': 1, 'order_hour_of_day': 12}
# 3421081  {'order_dow': 1, 'order_hour_of_day': 12}
# 3421082  {'order_dow': 6, 'order_hour_of_day': 14}
#
#                                                   products
# 0        {'product_id': [196, 14084, 12427, 26088, 2640...
# 1        {'product_id': [196, 10258, 12427, 13176, 2608...
# 2        {'product_id': [196, 12427, 10258, 25133, 3045...
# 3        {'product_id': [196, 12427, 10258, 25133, 2640...
# 4        {'product_id': [196, 12427, 10258, 25133, 1032...
# ...                                                    ...
# 3421078  {'product_id': [9405, 6846, 15700, 26503, 4121...
# 3421079  {'product_id': [6846, 9405, 41213, 24852, 1934...
# 3421080  {'product_id': [6846, 24852, 9405, 19348, 4121...
# 3421081  {'product_id': [24852, 9405, 16168, 39216, 141...
# 3421082                                                NaN
#
# [3421083 rows x 6 columns]

# %% [markdown]
# ### Loading data to MongoDB

# %%
products_df.rename(columns={"product_id": "_id", "product_name":"name", "aisle_id":"aisle", "department_id":"department"}, inplace=True)
random_us_addresses_df.rename(columns={"user_id":"_id", "user_address":"address"}, inplace=True)
orders_df.rename(columns={"order_id": "_id"}, inplace=True)

# %%
products_df.replace("\\N", None, inplace=True)
random_us_addresses_df.replace("\\N", None, inplace=True)
orders_df.replace("\\N", None, inplace=True)

# %%
products_dict = products_df.to_dict(orient='records')
users_dict = random_us_addresses_df.to_dict(orient='records')
orders_dict = orders_df.to_dict(orient='records')

# %%
from pymongo import MongoClient
def connect_to_mongodb():
    client = MongoClient("mongodb://localhost:27017")
    mydb = client["instacart"]
    orders = mydb["Orders"]
    products = mydb["Products"]
    users = mydb["Users"]
    return orders, products, users

orders, products, users = connect_to_mongodb()

# %%
def process_data(data):
    processed_data = []
    for documents in data:
        doc = {k: v for k, v in documents.items() if v is not None}
        processed_data.append(doc)
    return processed_data

# %%
products_data = process_data(products_dict)
orders_data = process_data(orders_dict)
users_data = process_data(users_dict)

# %%
products.delete_many({})
orders.delete_many({})
users.delete_many({})

products.insert_many(products_data)
orders.insert_many(orders_data)
users.insert_many(users_data)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# Cell In[56], line 6
#       3 users.delete_many({})
#       5 products.insert_many(products_data)
# ----> 6 orders.insert_many(orders_data)
#       7 users.insert_many(users_data)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymongo/_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymongo/collection.py:714, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     712 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     713 blk.ops = [doc for doc in gen()]
# --> 714 blk.execute(write_concern, session=session)
#     715 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymongo/bulk.py:513, in _Bulk.execute(self, write_concern, session)
#     511         self.execute_no_results(sock_info, generator, write_concern)
#     512 else:
# --> 513     return self.execute_command(generator, write_concern, session)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymongo/bulk.py:394, in _Bulk.execute_command(self, generator, write_concern, session)
#     391     client._retry_with_session(self.is_retryable, retryable_bulk, s, self)
#     393 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
# --> 394     _raise_bulk_write_error(full_result)
#     395 return full_result
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymongo/bulk.py:136, in _raise_bulk_write_error(full_result)
#     134 if full_result["writeErrors"]:
#     135     full_result["writeErrors"].sort(key=lambda error: error["index"])
# --> 136 raise BulkWriteError(full_result)
#
# BulkWriteError: batch op errors occurred, full error: {'writeErrors': [{'index': 0, 'code': 121, 'errmsg': 'Document failed validation', 'errInfo': {'failingDocumentId': 2539329, 'details': {'operatorName': '$and', 'clausesNotSatisfied': [{'index': 0, 'details': {'operatorName': '$jsonSchema', 'schemaRulesNotSatisfied': [{'operatorName': 'properties', 'propertiesNotSatisfied': [{'propertyName': 'products', 'details': [{'operatorName': 'bsonType', 'specifiedAs': {'bsonType': 'array'}, 'reason': 'type did not match', 'consideredValue': {'product_id': [196, 14084, 12427, 26088, 26405], 'reordered': [0, 0, 0, 0, 0]}, 'consideredType': 'object'}]}]}]}}]}}, 'op': {'_id': 2539329, 'user_id': 1, 'order_number': 1, 'datetime': {'order_dow': 2, 'order_hour_of_day': 8}, 'products': {'product_id': [196, 14084, 12427, 26088, 26405], 'reordered': [0, 0, 0, 0, 0]}}}], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': []}
